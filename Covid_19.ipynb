# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_profiling as pp
# %matplotlib inline

# %%
covid_data = pd.read_excel('covidreport.xlsx')

# %%
covid_data.head()
# Out:
#      # Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0  NaN          World    663665233   356974.0     6692545.0       849.0
# 1  NaN         Europe    242719800    15247.0     1980119.0       110.0
# 2  NaN           Asia    206595856   323654.0     1511157.0       635.0
# 3  NaN  North America    121262105     5992.0     1578160.0        28.0
# 4  1.0            USA    102407740        NaN     1117194.0         NaN
#
#   Total Recovered New Recovered Active Cases  Serious, Critical  \
# 0     635,734,338      +196,711   21,238,350            39709.0
# 1     236,784,979       +66,776    3,954,702             7569.0
# 2     193,360,313      +100,774   11,724,386            11331.0
# 3     116,064,993        +5,959    3,618,952             9463.0
# 4      99,367,089           NaN    1,923,457             4280.0
#
#    Tot Cases/ 1M pop  Deaths/ 1M pop   Total Tests  \
# 0            85142.0           858.6           NaN
# ...

# %%
covid_data.describe()
# Out:
#                 #   Total Cases      New Cases  Total Deaths  New Deaths  \
# count  230.000000  2.460000e+02      50.000000  2.410000e+02   36.000000
# mean   115.500000  1.348913e+07   35697.400000  1.388495e+05  117.916667
# std     66.539462  6.701059e+07   95291.807936  6.729827e+05  237.583955
# min      1.000000  9.000000e+00       3.000000  1.000000e+00    1.000000
# 25%     58.250000  2.747050e+04      53.000000  2.250000e+02    3.750000
# 50%    115.500000  2.545990e+05     663.500000  2.794000e+03   24.000000
# 75%    172.750000  1.992550e+06    6140.750000  1.966600e+04   57.500000
# max    230.000000  6.636652e+08  356974.000000  6.692545e+06  849.000000
#
#        Serious, Critical  Tot Cases/ 1M pop  Deaths/ 1M pop   Total Tests  \
# count         157.000000         230.000000      225.000000  2.130000e+02
# mean         1264.617834      190005.978261     1222.849778  3.230422e+07
# std          4939.747605      191468.719656     1260.643562  1.170682e+08
# ...

# %%
covid_data.head()
# Out:
#      # Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0  NaN          World    663665233   356974.0     6692545.0       849.0
# 1  NaN         Europe    242719800    15247.0     1980119.0       110.0
# 2  NaN           Asia    206595856   323654.0     1511157.0       635.0
# 3  NaN  North America    121262105     5992.0     1578160.0        28.0
# 4  1.0            USA    102407740        NaN     1117194.0         NaN
#
#   Total Recovered New Recovered Active Cases  Serious, Critical  \
# 0     635,734,338      +196,711   21,238,350            39709.0
# 1     236,784,979       +66,776    3,954,702             7569.0
# 2     193,360,313      +100,774   11,724,386            11331.0
# 3     116,064,993        +5,959    3,618,952             9463.0
# 4      99,367,089           NaN    1,923,457             4280.0
#
#    Tot Cases/ 1M pop  Deaths/ 1M pop   Total Tests  \
# 0            85142.0           858.6           NaN
# ...

# %%
covid_data.drop([0,1,2,3],inplace=True)

# %%
covid_data.reset_index(inplace=True)
covid_data.head()
# Out:
#    index    # Country, Other  Total Cases  New Cases  Total Deaths  \
# 0      4  1.0            USA    102407740        NaN     1117194.0
# 1      5  NaN  South America     66764128     9270.0     1341457.0
# 2      6  2.0          India     44678937        NaN      530698.0
# 3      7  3.0         France     39245937        NaN      161715.0
# 4      8  4.0        Germany     37313240        NaN      161133.0
#
#    New Deaths Total Recovered New Recovered Active Cases  Serious, Critical  \
# 0         NaN      99,367,089           NaN    1,923,457             4280.0
# 1        52.0      64,253,133       +23,085    1,169,538            10342.0
# 2         NaN      44,143,665           NaN        4,574              698.0
# 3         NaN      38,169,715           NaN      914,507              869.0
# 4         NaN      36,574,400       +32,300      577,707             1406.0
#
#    Tot Cases/ 1M pop  Deaths/ 1M pop   Total Tests  \
# ...

# %%
covid_data.isnull().sum()
# Out:
# index                                                0
# #                                                   12
# Country, Other                                       1
# Total Cases                                          0
# New Cases                                          196
# Total Deaths                                         5
# New Deaths                                         210
# Total Recovered                                     20
# New Recovered                                      189
# Active Cases                                        19
# Serious, Critical                                   89
# Tot Cases/ 1M pop                                   13
# Deaths/ 1M pop                                      18
# Total Tests                                         29
# Tests/ \n                                1M pop     29
# Population                                          14
# dtype: int64

# %%
covid_data.columns
# Out:
# Index(['index', '#', 'Country, Other', 'Total Cases', 'New Cases',
#        'Total Deaths', 'New Deaths', 'Total Recovered', 'New Recovered',
#        'Active Cases', 'Serious, Critical', 'Tot Cases/ 1M pop',
#        'Deaths/ 1M pop', 'Total Tests',
#        'Tests/ \n                                1M pop', 'Population'],
#       dtype='object')

# %%
covid_data['Country, Other'].unique()
# Out:
# array(['USA', 'South America', 'India', 'France', 'Germany', 'Brazil',
#        'Japan', 'S. Korea', 'Italy', 'UK', 'Russia', 'Turkey', 'Spain',
#        'Oceania', 'Africa', 'Vietnam', 'Australia', 'Argentina', 'Taiwan',
#        'Netherlands', 'Iran', 'Mexico', 'Indonesia', 'Poland', 'Colombia',
#        'Austria', 'Portugal', 'Greece', 'Ukraine', 'Chile', 'Malaysia',
#        'DPRK', 'Israel', 'Thailand', 'Belgium', 'Czechia', 'Canada',
#        'Peru', 'Switzerland', 'Philippines', 'South Africa', 'Romania',
#        'Denmark', 'Sweden', 'Hong Kong', 'Iraq', 'Serbia', 'Singapore',
#        'Hungary', 'New Zealand', 'Bangladesh', 'Slovakia', 'Georgia',
#        'Jordan', 'Ireland', 'Pakistan', 'Norway', 'Finland', 'Kazakhstan',
#        'Slovenia', 'Bulgaria', 'Lithuania', 'Morocco', 'Croatia',
#        'Lebanon', 'Guatemala', 'Costa Rica', 'Bolivia', 'Tunisia', 'Cuba',
#        'UAE', 'Ecuador', 'Panama', 'Uruguay', 'Mongolia', 'Nepal',
# ...

# %%
req_col = ['Country, Other','Total Cases','Total Deaths','Total Tests','Population']

# %%
covid_data.shape
# Out:
# (242, 16)

# %%
data1 = covid_data[req_col]

# %%
data1.head()
# Out:
#   Country, Other  Total Cases  Total Deaths   Total Tests    Population
# 0            USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 1  South America     66764128     1341457.0           NaN           NaN
# 2          India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3         France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4        Germany     37313240      161133.0  1.223324e+08  8.388360e+07

# %%
data1.columns=['Country','Total Cases','Total Deaths','Total Tests','Population']

# %%
data1
# Out:
#            Country  Total Cases  Total Deaths   Total Tests    Population
# 0              USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 1    South America     66764128     1341457.0           NaN           NaN
# 2            India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3           France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4          Germany     37313240      161133.0  1.223324e+08  8.388360e+07
# ..             ...          ...           ...           ...           ...
# 237         Total:     66764128     1341457.0           NaN           NaN
# 238         Total:     13582848       23298.0           NaN           NaN
# 239         Total:     12739775      258339.0           NaN           NaN
# 240         Total:          721          15.0           NaN           NaN
# 241         Total:    663665233     6692545.0           NaN           NaN
#
# [242 rows x 5 columns]

# %%
data1['Country'].unique()
# Out:
# array(['USA', 'South America', 'India', 'France', 'Germany', 'Brazil',
#        'Japan', 'S. Korea', 'Italy', 'UK', 'Russia', 'Turkey', 'Spain',
#        'Oceania', 'Africa', 'Vietnam', 'Australia', 'Argentina', 'Taiwan',
#        'Netherlands', 'Iran', 'Mexico', 'Indonesia', 'Poland', 'Colombia',
#        'Austria', 'Portugal', 'Greece', 'Ukraine', 'Chile', 'Malaysia',
#        'DPRK', 'Israel', 'Thailand', 'Belgium', 'Czechia', 'Canada',
#        'Peru', 'Switzerland', 'Philippines', 'South Africa', 'Romania',
#        'Denmark', 'Sweden', 'Hong Kong', 'Iraq', 'Serbia', 'Singapore',
#        'Hungary', 'New Zealand', 'Bangladesh', 'Slovakia', 'Georgia',
#        'Jordan', 'Ireland', 'Pakistan', 'Norway', 'Finland', 'Kazakhstan',
#        'Slovenia', 'Bulgaria', 'Lithuania', 'Morocco', 'Croatia',
#        'Lebanon', 'Guatemala', 'Costa Rica', 'Bolivia', 'Tunisia', 'Cuba',
#        'UAE', 'Ecuador', 'Panama', 'Uruguay', 'Mongolia', 'Nepal',
# ...

# %%
data2 = data1.drop(data1[data1.Country=='Total:'].index)

# %%
data2.Country.unique()
# Out:
# array(['USA', 'South America', 'India', 'France', 'Germany', 'Brazil',
#        'Japan', 'S. Korea', 'Italy', 'UK', 'Russia', 'Turkey', 'Spain',
#        'Oceania', 'Africa', 'Vietnam', 'Australia', 'Argentina', 'Taiwan',
#        'Netherlands', 'Iran', 'Mexico', 'Indonesia', 'Poland', 'Colombia',
#        'Austria', 'Portugal', 'Greece', 'Ukraine', 'Chile', 'Malaysia',
#        'DPRK', 'Israel', 'Thailand', 'Belgium', 'Czechia', 'Canada',
#        'Peru', 'Switzerland', 'Philippines', 'South Africa', 'Romania',
#        'Denmark', 'Sweden', 'Hong Kong', 'Iraq', 'Serbia', 'Singapore',
#        'Hungary', 'New Zealand', 'Bangladesh', 'Slovakia', 'Georgia',
#        'Jordan', 'Ireland', 'Pakistan', 'Norway', 'Finland', 'Kazakhstan',
#        'Slovenia', 'Bulgaria', 'Lithuania', 'Morocco', 'Croatia',
#        'Lebanon', 'Guatemala', 'Costa Rica', 'Bolivia', 'Tunisia', 'Cuba',
#        'UAE', 'Ecuador', 'Panama', 'Uruguay', 'Mongolia', 'Nepal',
# ...

# %%
data2.head()
# Out:
#          Country  Total Cases  Total Deaths   Total Tests    Population
# 0            USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 1  South America     66764128     1341457.0           NaN           NaN
# 2          India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3         France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4        Germany     37313240      161133.0  1.223324e+08  8.388360e+07

# %%
data2.fillna(0,inplace=True)

# %%
data2.isnull().sum()
# Out:
# Country         0
# Total Cases     0
# Total Deaths    0
# Total Tests     0
# Population      0
# dtype: int64

# %%
x = data2.Country[0:20]
y = data2.loc[:20,'Total Cases']

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.barplot(y,x)
plt.title('Countries with Max cases')
plt.show()
# Out:
# D:\APPS-FILES\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(data2.Population)
plt.plot(data2.loc[:,'Total Deaths'])
plt.xlabel('Population')
plt.ylabel('Total Deaths')
plt.show()

# %%
data2
# Out:
#               Country  Total Cases  Total Deaths   Total Tests    Population
# 0                 USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 1       South America     66764128     1341457.0  0.000000e+00  0.000000e+00
# 2               India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3              France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4             Germany     37313240      161133.0  1.223324e+08  8.388360e+07
# ..                ...          ...           ...           ...           ...
# 229  Diamond Princess          712          13.0  0.000000e+00  0.000000e+00
# 230              Niue          458           0.0  0.000000e+00  1.622000e+03
# 231      Vatican City           29           0.0  0.000000e+00  7.990000e+02
# 232    Western Sahara           10           1.0  0.000000e+00  6.261610e+05
# 233        MS Zaandam            9           2.0  0.000000e+00  0.000000e+00
#
# [234 rows x 5 columns]

# %%
data2['Per_Death']=data2['Total Deaths']/data2['Population'] * 100

# %%
data2
# Out:
#               Country  Total Cases  Total Deaths   Total Tests    Population  \
# 0                 USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 1       South America     66764128     1341457.0  0.000000e+00  0.000000e+00
# 2               India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3              France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4             Germany     37313240      161133.0  1.223324e+08  8.388360e+07
# ..                ...          ...           ...           ...           ...
# 229  Diamond Princess          712          13.0  0.000000e+00  0.000000e+00
# 230              Niue          458           0.0  0.000000e+00  1.622000e+03
# 231      Vatican City           29           0.0  0.000000e+00  7.990000e+02
# 232    Western Sahara           10           1.0  0.000000e+00  6.261610e+05
# 233        MS Zaandam            9           2.0  0.000000e+00  0.000000e+00
#
#      Per_Death
# 0     0.333685
# ...

# %%
data2.isnull().sum()
# Out:
# Country         0
# Total Cases     0
# Total Deaths    0
# Total Tests     0
# Population      0
# Per_Death       0
# dtype: int64

# %%
data2.head()
# Out:
#          Country  Total Cases  Total Deaths   Total Tests    Population  \
# 0            USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 1  South America     66764128     1341457.0  0.000000e+00  0.000000e+00
# 2          India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3         France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4        Germany     37313240      161133.0  1.223324e+08  8.388360e+07
#
#    Per_Death
# 0   0.333685
# 1        inf
# 2   0.037728
# 3   0.246575
# 4   0.192091

# %%
data2
# Out:
#               Country  Total Cases  Total Deaths   Total Tests    Population  \
# 0                 USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 1       South America     66764128     1341457.0  0.000000e+00  0.000000e+00
# 2               India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3              France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4             Germany     37313240      161133.0  1.223324e+08  8.388360e+07
# ..                ...          ...           ...           ...           ...
# 229  Diamond Princess          712          13.0  0.000000e+00  0.000000e+00
# 230              Niue          458           0.0  0.000000e+00  1.622000e+03
# 231      Vatican City           29           0.0  0.000000e+00  7.990000e+02
# 232    Western Sahara           10           1.0  0.000000e+00  6.261610e+05
# 233        MS Zaandam            9           2.0  0.000000e+00  0.000000e+00
#
#      Per_Death
# 0    33.368471
# ...

# %%
data2.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
data2.dropna(inplace=True)

# %%
data2
# Out:
#                Country  Total Cases  Total Deaths   Total Tests    Population  \
# 0                  USA    102407740     1117194.0  1.151492e+09  3.348053e+08
# 2                India     44678937      530698.0  9.099932e+08  1.406632e+09
# 3               France     39245937      161715.0  2.714902e+08  6.558452e+07
# 4              Germany     37313240      161133.0  1.223324e+08  8.388360e+07
# 5               Brazil     36275146      693604.0  6.377617e+07  2.153536e+08
# ..                 ...          ...           ...           ...           ...
# 226         Montserrat         1403           8.0  1.776200e+04  4.965000e+03
# 227  Wallis and Futuna          761           7.0  2.050800e+04  1.098200e+04
# 230               Niue          458           0.0  0.000000e+00  1.622000e+03
# 231       Vatican City           29           0.0  0.000000e+00  7.990000e+02
# 232     Western Sahara           10           1.0  0.000000e+00  6.261610e+05
#
#      Per_Death
# 0    33.368471
# ...

# %%
# Country with Max percetage of death
max_death=data2.loc[data2['Per_Death']==data2.Per_Death.max(),'Country']

# %%
print(max_death)
# Out:
# 37    Peru
# Name: Country, dtype: object

# %%
data3=data2.sort_values(by=['Per_Death'],ascending=False)

# %%
data3
# Out:
#                     Country  Total Cases  Total Deaths  Total Tests  \
# 37                     Peru      4451074      218146.0   37298236.0
# 60                 Bulgaria      1291548       38097.0   10891621.0
# 48                  Hungary      2185816       48495.0   11394556.0
# 99   Bosnia and Herzegovina       400979       16226.0    1882052.0
# 101         North Macedonia       345603        9614.0    2206417.0
# ..                      ...          ...           ...          ...
# 222                  Tuvalu         2805           0.0          0.0
# 223        Falkland Islands         1930           0.0       8632.0
# 224            Saint Helena         1806           0.0          0.0
# 230                    Niue          458           0.0          0.0
# 231            Vatican City           29           0.0          0.0
#
#      Population  Per_Death
# 37   33684208.0  64.762099
# 60    6844597.0  55.659961
# 48    9606259.0  50.482711
# 99    3249317.0  49.936648
# ...

# %%
data3.Per_Death.max()
# Out:
# 64.7620986071574

# %%
x1=data3.Per_Death[0:10]
y1= data3.Country[0:10]

# %%
sns.barplot(x1,y1)
plt.title('Max Percenatage of Death w.r.t Population')
plt.show()
# Out:
# D:\APPS-FILES\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
